# %% [markdown]
# Crear un diccionario

# %%
est = {"Regina":[1,2,3,4,5],"Ana":[6,7,8,9,10], "Esteve":[11,12,13,14,15],"Llop":[16,17,18,19,20], "Juanpa":[21,22,23,24,25]} #Base de datos del diccionario. El nombre son keys y los números son values

# %%
type(est)
# Out:
# dict

# %%
import pandas as pd

# %%
pd.DataFrame(est)  #Poner el diccionario dentro de una tabla
# Out:
#    Regina  Ana  Esteve  Llop  Juanpa
# 0       1    6      11    16      21
# 1       2    7      12    17      22
# 2       3    8      13    18      23
# 3       4    9      14    19      24
# 4       5   10      15    20      25

# %% [markdown]
# Letura de datos a través de API:
#
# API significa “interfaz de programación de aplicaciones”. En el contexto de las API, la palabra aplicación se refiere a cualquier software con una función distinta. Las API son mecanismos que permiten que dos componentes de software se comuniquen entre sí mediante un conjunto de definiciones y protocolos .
#
# Fuente: [API](https://translate.google.com/translate?u=https://aws.amazon.com/what-is/api/&hl=es&sl=en&tl=es&client=rq&prev=search#:~:text=APIs%20are%20mechanisms%20that%20enable,weather%20updates%20on%20your%20phone.)

# %%
import yfinance as yf #yahoofinance. interacción con la API que se llama yahoo finance

# %%
ticker = " AAPL "
aapl = yf.download(ticker, start="2004-03-12", end="2024-03-12")
aapl
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-03-12    0.487857    0.496071    0.485179    0.492143    0.416648
# 2004-03-15    0.482679    0.488393    0.468929    0.472321    0.399867
# 2004-03-16    0.474107    0.475179    0.453393    0.461071    0.390343
# 2004-03-17    0.463571    0.471071    0.460357    0.467679    0.395937
# 2004-03-18    0.463214    0.465357    0.456964    0.458393    0.388075
# ...                ...         ...         ...         ...         ...
# 2024-03-05  170.759995  172.039993  169.619995  170.119995  170.119995
# 2024-03-06  171.059998  171.240005  168.679993  169.119995  169.119995
# 2024-03-07  169.149994  170.729996  168.490005  169.000000  169.000000
# 2024-03-08  169.000000  173.699997  168.940002  170.729996  170.729996
# 2024-03-11  172.940002  174.380005  172.050003  172.750000  172.750000
#
#                Volume
# Date
# ...
